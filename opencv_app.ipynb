# %% [markdown]
# <a href="https://colab.research.google.com/github/CrucifierBladex/self_driving_car/blob/main/opencv_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
INPUT IMAGE
# Out:
# <PIL.Image.Image image mode=RGB size=650x430 at 0x7FF15D84AEB8>

# %% [markdown]
# APPLYING GAUSSIAN BLUR FOR SMOOTHENING THE IMAGE

# %%
image.shape
# Out:
# (430, 650, 3)

# %% [markdown]
# CANNY EDGE DETECTION USING OPENCV

# %%
# Out:
# <PIL.Image.Image image mode=L size=650x430 at 0x7FF15D75C4A8>

# %% [markdown]
# REGION OF INTEREST EXTRACTION USING MASKING TECHNIQUE

# %%
# Out:
# <PIL.Image.Image image mode=L size=650x430 at 0x7FF15D123630>

# %% [markdown]
# APPLYING HOUGH LINE TRANSFORM FOR PIXEL EXTRAPOLATION

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=650x430 at 0x7FF15D0D7AC8>

# %% [markdown]
# APPLYING WEIGHTED AVERAGE OF THE REAL AND THE HOUGH TRANSFORMED IMAGE

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=650x430 at 0x7FF15D0E2978>
